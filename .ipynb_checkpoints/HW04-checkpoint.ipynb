# %% [markdown]
# ## 此資料為：[文化部所收錄台灣特色書店的資料](https://data.gov.tw/dataset/6224)
# * 資料來源：[政府資料開放平台](https://data.gov.tw/)
# * 利用資料探勘整理資料

# %%
import jieba
import jieba.analyse
import pandas as pd
import numpy as np
from collections import Counter

# %%
#讀取資料
orgdata = pd.read_csv('FeaturedBookstore.csv')

# %%
orgdata.head()
# Out:
#       name                                     representImage  \
# 0     人生書局  http://cloud.culture.tw/e_new_upload/cms/image...
# 1     一本書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 2     書集喜室  http://cloud.culture.tw/e_new_upload/cms/image...
# 3     樸食小舖  http://cloud.culture.tw/e_new_upload/cms/image...
# 4  小陽。日栽書屋  http://cloud.culture.tw/e_new_upload/cms/image...
#
#                                                intro               address  \
# 0  位在鹽埕區的新樂街上，看守著台灣戰後的歷史。早年人生書局只賣自己出版的書籍，是個相當「冷門」...               新樂街145號
# 1  位於台中文創園區對面的一本書店，與許多手作文創產業合作，在店內會舉辦教學課程。時常舉辦新詩朗...       復興路3段348巷2-2號1樓
# 2  隱身在鹿港巷弄中的書集喜室，是一間二手書店，原本一棟快要廢棄的日治時期老屋，被店主買下，經過...          彰化縣鹿港鎮杉行街20號
# 3  樸食小舖，我們是「市集裡的書店」!\r\n\r\n我們原先在新竹市開有機複合餐廳，後來移居苗...  新竹市光復路二段101號(清大成功湖邊)
# 4  一點勇氣將小陽。春日子更明確蛻變成小陽。日栽書屋，走過那段和伙伴一起的充滿春分生命力的日子，...           屏東市中山路清營巷1號
#
#     longitude   latitude                openTime phone  \
# 0  120.281814  22.620168       一～日｜09:00 - 21:00   NaN
# 1  120.679643  24.132733       三～日｜12:00 - 17:00   NaN
# 2  120.435059  24.057213        週三至週日11:00-17:30   NaN
# 3  120.969102  24.806942  每月第一周和第三周的周六，早上九點到下午兩點   NaN
# 4  120.501205  22.677970       週四至週日 14:00-20:00   NaN
#
#                     email headCityName  cityName groupTypeName
# 0                     NaN          NaN  高雄市  鹽埕區          實體書店
# 1                     NaN          NaN   臺中市  南區          實體書店
# 2                     NaN          NaN  彰化縣  鹿港鎮          實體書店
# 3  nicole571105@gmail.com       竹蜻蜓綠市集  新竹市  新竹市          實體書店
# 4   ssunville@hotmail.com          NaN  屏東縣  屏東市          實體書店

# %%
documents = ['我是臺灣師範大學科技系114級徐嫚謙']#一段字串
# 精確模式
for sentence in documents:
    seg_list = jieba.cut(sentence)#用jieba做cut斷詞
    print('/'.join(seg_list))#印出來的內容用斜線隔開
# Out:
# 我/是/臺灣師範大學/科技系/114級/徐嫚謙

# %%
jieba.load_userdict('./userdict.txt')#自己建立斷詞文本

for sentence in documents:
    seg_list = jieba.cut(sentence)
    print('/'.join(seg_list))
# Out:
# 我/是/臺灣師範大學/科技系/114級/徐嫚謙

# %%
#新增一個新欄位
orgdata['seg'] = ""
orgdata.head()
# Out:
#       name                                     representImage  \
# 0     人生書局  http://cloud.culture.tw/e_new_upload/cms/image...
# 1     一本書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 2     書集喜室  http://cloud.culture.tw/e_new_upload/cms/image...
# 3     樸食小舖  http://cloud.culture.tw/e_new_upload/cms/image...
# 4  小陽。日栽書屋  http://cloud.culture.tw/e_new_upload/cms/image...
#
#                                                intro               address  \
# 0  位在鹽埕區的新樂街上，看守著台灣戰後的歷史。早年人生書局只賣自己出版的書籍，是個相當「冷門」...               新樂街145號
# 1  位於台中文創園區對面的一本書店，與許多手作文創產業合作，在店內會舉辦教學課程。時常舉辦新詩朗...       復興路3段348巷2-2號1樓
# 2  隱身在鹿港巷弄中的書集喜室，是一間二手書店，原本一棟快要廢棄的日治時期老屋，被店主買下，經過...          彰化縣鹿港鎮杉行街20號
# 3  樸食小舖，我們是「市集裡的書店」!\r\n\r\n我們原先在新竹市開有機複合餐廳，後來移居苗...  新竹市光復路二段101號(清大成功湖邊)
# 4  一點勇氣將小陽。春日子更明確蛻變成小陽。日栽書屋，走過那段和伙伴一起的充滿春分生命力的日子，...           屏東市中山路清營巷1號
#
#     longitude   latitude                openTime phone  \
# 0  120.281814  22.620168       一～日｜09:00 - 21:00   NaN
# 1  120.679643  24.132733       三～日｜12:00 - 17:00   NaN
# 2  120.435059  24.057213        週三至週日11:00-17:30   NaN
# 3  120.969102  24.806942  每月第一周和第三周的周六，早上九點到下午兩點   NaN
# 4  120.501205  22.677970       週四至週日 14:00-20:00   NaN
#
#                     email headCityName  cityName groupTypeName seg
# 0                     NaN          NaN  高雄市  鹽埕區          實體書店
# 1                     NaN          NaN   臺中市  南區          實體書店
# 2                     NaN          NaN  彰化縣  鹿港鎮          實體書店
# 3  nicole571105@gmail.com       竹蜻蜓綠市集  新竹市  新竹市          實體書店
# 4   ssunville@hotmail.com          NaN  屏東縣  屏東市          實體書店

# %%
jieba.analyse.set_stop_words('stopwords.txt') #自己建一個贅字檔
index = 0
for documents in orgdata['intro']: #將檔案的intro欄位利用迴圈存入documents
    seg_list = jieba.analyse.extract_tags(documents, 150) #150是前150個權重最高的單詞
    #seg_list = jieba.lcut(documents) #不刪除贅字
    orgdata['seg'].iloc[index] = seg_list #存入seg_list
    index += 1
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19532\776467664.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
orgdata['seg']
# Out:
# 0      [位在, 鹽埕區, 新樂街, 台灣, 戰後, 歷史, 人生書局, 只賣, 相當, 冷門, 佛...
# 1      [創園區, 對面, 許多手, 創產業, 內會, 舉辦, 教學課程, 時常舉, 新詩朗讀會, ...
# 2      [喜室, 書集, 茶屋, 隱身, 巷弄, 一間, 二手書, 一棟, 廢棄, 日治, 時期, ...
# 3      [樸食小舖, 市集裡的書店, 沒有, 大門, 市集, 有機複合餐廳, 公館, 鄉間, 展開,...
# 4      [小陽, 一點, 勇氣將, 更明確, 蛻變, 日栽書屋, 走過, 充滿, 延續, 發光, 發...
#                              ...
# 104    [池上, 借冊所, 旅人, 交流, 體驗世界, 背包客, 熱愛臺灣, 暫居, 開設, 喜歡,...
# 105    [走走池上, 旅人, 半開放式, 空間, 歡迎, 翻閱, 放慢腳步, 品嚐, 飲品, 他鄉,...
# 106    [金門, 二手書, 首間, 經營, 買賣, 點心, 長期, 徵求, 換宿, 圖片, 臉書, ...
# 107    [撥橘, 咖啡, 本東, 創作, 裝訂, 內頁, Huei, 三明治, 小店, 封面, 小小...
# 108    [聯經, 圖書門市, 陳列, 銷售, 出版, 企管, 1986, 設有, 專業, 出版品, ...
# Name: seg, Length: 109, dtype: object

# %%
date_split = orgdata['cityName'].iloc[0].split(' ') #建立一個新的欄位放入用空格格開的cityName

# %%
date_split[0] #取出用空格隔開後的第一個文字是縣市
# Out:
# '高雄市'

# %%
#新增一個city欄位利用迴圈存入縣市
orgdata['city'] = ""  
index = 0
for documents in orgdata['cityName']: 
    date_split = documents.split(' ')
    orgdata['city'].iloc[index] = date_split[0]
    index += 1
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19532\1863161369.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
orgdata.head()
# Out:
#       name                                     representImage  \
# 0     人生書局  http://cloud.culture.tw/e_new_upload/cms/image...
# 1     一本書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 2     書集喜室  http://cloud.culture.tw/e_new_upload/cms/image...
# 3     樸食小舖  http://cloud.culture.tw/e_new_upload/cms/image...
# 4  小陽。日栽書屋  http://cloud.culture.tw/e_new_upload/cms/image...
#
#                                                intro               address  \
# 0  位在鹽埕區的新樂街上，看守著台灣戰後的歷史。早年人生書局只賣自己出版的書籍，是個相當「冷門」...               新樂街145號
# 1  位於台中文創園區對面的一本書店，與許多手作文創產業合作，在店內會舉辦教學課程。時常舉辦新詩朗...       復興路3段348巷2-2號1樓
# 2  隱身在鹿港巷弄中的書集喜室，是一間二手書店，原本一棟快要廢棄的日治時期老屋，被店主買下，經過...          彰化縣鹿港鎮杉行街20號
# 3  樸食小舖，我們是「市集裡的書店」!\r\n\r\n我們原先在新竹市開有機複合餐廳，後來移居苗...  新竹市光復路二段101號(清大成功湖邊)
# 4  一點勇氣將小陽。春日子更明確蛻變成小陽。日栽書屋，走過那段和伙伴一起的充滿春分生命力的日子，...           屏東市中山路清營巷1號
#
#     longitude   latitude                openTime phone  \
# 0  120.281814  22.620168       一～日｜09:00 - 21:00   NaN
# 1  120.679643  24.132733       三～日｜12:00 - 17:00   NaN
# 2  120.435059  24.057213        週三至週日11:00-17:30   NaN
# 3  120.969102  24.806942  每月第一周和第三周的周六，早上九點到下午兩點   NaN
# 4  120.501205  22.677970       週四至週日 14:00-20:00   NaN
#
#                     email headCityName  cityName groupTypeName  \
# 0                     NaN          NaN  高雄市  鹽埕區          實體書店
# 1                     NaN          NaN   臺中市  南區          實體書店
# 2                     NaN          NaN  彰化縣  鹿港鎮          實體書店
# 3  nicole571105@gmail.com       竹蜻蜓綠市集  新竹市  新竹市          實體書店
# 4   ssunville@hotmail.com          NaN  屏東縣  屏東市          實體書店
#
#                                                  seg city
# 0  [位在, 鹽埕區, 新樂街, 台灣, 戰後, 歷史, 人生書局, 只賣, 相當, 冷門, 佛...  高雄市
# 1  [創園區, 對面, 許多手, 創產業, 內會, 舉辦, 教學課程, 時常舉, 新詩朗讀會, ...  臺中市
# 2  [喜室, 書集, 茶屋, 隱身, 巷弄, 一間, 二手書, 一棟, 廢棄, 日治, 時期, ...  彰化縣
# 3  [樸食小舖, 市集裡的書店, 沒有, 大門, 市集, 有機複合餐廳, 公館, 鄉間, 展開,...  新竹市
# 4  [小陽, 一點, 勇氣將, 更明確, 蛻變, 日栽書屋, 走過, 充滿, 延續, 發光, 發...  屏東縣

# %%
#利用Counter抓出city裡不重複的資料
Counter(orgdata['city']).keys()
# Out:
# dict_keys(['高雄市', '臺中市', '彰化縣', '新竹市', '屏東縣', '臺北市', '新北市', '新竹縣', '花蓮縣', '宜蘭縣', '嘉義市', '嘉義縣', '臺南市', '臺東縣', '桃園市', '南投縣', '苗栗縣', '澎湖縣', '金門縣'])

# %%
#抓出city裡每個縣市重複幾次
words = list(orgdata['city'])
show_key = pd.DataFrame(Counter(words).keys())
show_values = pd.DataFrame(Counter(words).values())

# %%
#建立dataframe放入資料
df = [show_key, show_values]

# %%
result = pd.concat(df, axis=1)
result.columns = ['city', 'freguency']
result
# Out:
#    city  freguency
# 0   高雄市          8
# 1   臺中市         13
# 2   彰化縣          3
# 3   新竹市          3
# 4   屏東縣          4
# 5   臺北市         35
# 6   新北市          7
# 7   新竹縣          8
# 8   花蓮縣          4
# 9   宜蘭縣          3
# 10  嘉義市          3
# 11  嘉義縣          1
# 12  臺南市          4
# 13  臺東縣          7
# 14  桃園市          2
# 15  南投縣          1
# 16  苗栗縣          1
# 17  澎湖縣          1
# 18  金門縣          1

# %%
import plotly.express as px
import pandas as pd

#用px套件做統計圖
px.bar(result, x='city', y='freguency', title='特色書店各縣市數量')
# Out:
# <div>                            <div id="dbed5a5f-32ba-46b3-a599-577f4f863869" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbed5a5f-32ba-46b3-a599-577f4f863869")) {                    Plotly.newPlot(                        "dbed5a5f-32ba-46b3-a599-577f4f863869",                        [{"alignmentgroup":"True","hovertemplate":"city=%{x}<br>freguency=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\u9ad8\u96c4\u5e02","\u81fa\u4e2d\u5e02","\u5f70\u5316\u7e23","\u65b0\u7af9\u5e02","\u5c4f\u6771\u7e23","\u81fa\u5317\u5e02","\u65b0\u5317\u5e02","\u65b0\u7af9\u7e23","\u82b1\u84ee\u7e23","\u5b9c\u862d\u7e23","\u5609\u7fa9\u5e02","\u5609\u7fa9\u7e23","\u81fa\u5357\u5e02","\u81fa\u6771\u7e23","\u6843\u5712\u5e02","\u5357\u6295\u7e23","\u82d7\u6817\u7e23","\u6f8e\u6e56\u7e23","\u91d1\u9580\u7e23"],"xaxis":"x","y":[8,13,3,3,4,35,7,8,4,3,3,1,4,7,2,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888," ...

# %%
#可以只取出臺北市的特色書局
show_sub = orgdata['city']=='臺北市'
subdata = orgdata[show_sub]
subdata
# Out:
#                      name                                     representImage  \
# 5                    世界書局  http://cloud.culture.tw/e_new_upload/cms/image...
# 6                    人文書舍  http://cloud.culture.tw/e_new_upload/cms/image...
# 7                    青鳥書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 8                    松林書局  http://cloud.culture.tw/e_new_upload/cms/image...
# 9                    三民書局  http://cloud.culture.tw/e_new_upload/cms/image...
# 10              聯經書房‧上海書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 11              流浪ing旅遊書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 12                   水準書局  http://cloud.culture.tw/e_new_upload/cms/image...
# 13   河邊生活Liv'in Riverside  http://cloud.culture.tw/e_new_upload/cms/image...
# 14           紀州庵文學森林 文創書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 15              Mangasick  http://cloud.culture.tw/e_new_upload/cms/image...
# 16                   校園書房  http://cloud.culture.tw/e_new_upload/cms/image...
# 17                  阿維的書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 18                    書香城  http://cloud.culture.tw/e_new_upload/cms/image...
# 19                 百城堂古書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 20                93巷人文空間  http://cloud.culture.tw/e_new_upload/cms/image...
# 21            朋丁 pon ding  http://cloud.culture.tw/e_new_upload/cms/image...
# 23              水牛書店（台北店）  http://cloud.culture.tw/e_new_upload/cms/image...
# 24                   信義書局  http://cloud.culture.tw/e_new_upload/cms/image...
# 25                   閱樂書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 26                 桑格設計書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 28                   左轉有書  http://cloud.culture.tw/e_new_upload/cms/image...
# 29                   公共冊所  http://cloud.culture.tw/e_new_upload/cms/image...
# 68                  純良社書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 69                   戲台書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 70               親子天下Club  http://cloud.culture.tw/e_new_upload/cms/image...
# 71                   櫞椛文庫  http://cloud.culture.tw/h_upload_ccacloud/cms/...
# 72                   微貳獨冊  http://cloud.culture.tw/e_new_upload/cms/image...
# 73    RE BOOK STORE 閱二手書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 74              竹風書苑（公館店）  http://cloud.culture.tw/e_new_upload/cms/image...
# 75              竹風書苑（南港店）  http://cloud.culture.tw/e_new_upload/cms/image...
# 76                 愛閱二手書坊  http://cloud.culture.tw/e_new_upload/cms/image...
# 92                萬金喵二手書店  http://cloud.culture.tw/e_new_upload/cms/image...
# 97                   小高的店  http://cloud.culture.tw/e_new_upload/cms/image...
# 100                   恬野書  http://cloud.culture.tw/e_new_upload/cms/image...
#
#                                                  intro  \
# 5    以其創辦人特有的「紅屋」屹立於重慶南路，是重慶南路書街風景中極具特色的一家書店。過去只販售自...
# 6    創始人是隨著國民政府來台的老兵，喜歡逛舊書攤的他退伍後便投入舊書行列，在牯嶺街的長巷中開設了...
# 7    建一間屬於自由的書店\r\n不是為了獨立、不是為了隔絕，是為了自由；自由才可以追尋幸福，這是...
# 8    據說是當年牯嶺街舊書攤中第一個有名號的店，也是目前牯嶺街僅存的舊書店當中最老字號的。堆疊滿屋...
# 9    在重慶南路上已有超過半個世紀的歷史，可說是重慶南路書街的重要代表店之一。三民以所謂的「圖書館...
# 10   為聯經出版公司位於新生南路上的門市，不過並不侷限於自家出版品。一樓聯經書房的書籍以人文社科類...
# 11   流浪ing是一間以旅遊為主題的書店，各式各樣的旅遊書籍，分門別類地放置在書櫃上每一個適當的空...
# 12   從早期的店址搬遷到現在的浦城街，開業已超過40年，因價格便宜而吸引許多年輕學子光顧。店內書籍...
# 13   【河邊生活】是一個推廣台灣文化的複合式平台。我們透過結合書店、藝廊與文化講座的方式，經由閱讀...
# 14   由位居城南的紀州庵輻射出去，涵括鄰近的同安街、廈門街、金門街、牯嶺街，遠至師大與臺大學區，是...
# 15   Mangasick是2013年於台灣台北市公館開業的次文化漫畫書店，提供書籍內閱服務，亦販售...
# 16   是台大地區歷史悠久的書店，以基督教書籍及其相關週邊為主要銷售產品。除一樓書籍區外，二樓有流行...
# 17   位於懷寧街上，是重慶南路一帶少數的二手書店。以販售大專二手教科書為主，也兼有一些一般人文、藝...
# 18   原是廈門街的「瑩橋書店」，其後遷至牯嶺街才更名為書香城，可說是目前牯嶺街一帶最具規模，也比較...
# 19   原位於光華商場內，僅一坪半的店面空間卻是台灣史料的蒐羅重地。商場拆除後，百城堂成為唯一留駐新...
# 20   遠見．天下文化事業群 專屬空間 / 學．書．食．飲．花\r\n\r\n一個不大的空間，有書、...
# 21   一個由台灣、印尼，日本三個朋友共同透過編輯概念、與各路人馬合作，出產各式形體與物件的計畫空間...
# 23                          http://www.buffalo1966.tw/
# 24   位於復興南路，1977年創業於中國書城，店主興趣廣泛，而以個人品味挑選店內藝術人文叢書，加上...
# 25   閱樂書店是這座城市最奇幻的書店。建於1954年，原為松山菸場內位於製菸工廠南側的育嬰室，代表...
# 26   桑格是頗負盛名的設計書類專賣店，營業迄今已逾30年。店內擺賣著各式歐、美、日的工業、商業設計...
# 28   左轉文化承繼開業六年的慕哲咖啡，除了週週對談、辯論，關注公共議題的沙龍講座，增設「左轉有書」...
# 29   公共冊所在各樣活動的辦理上均十分投入，年輕的店主人是個音樂創作人，認為一群人想做些甚麼，擁有...
# 68                        純良社是一家社區書店，希望成為社區裡買書找書聊書的據點。
# 69   書店紅磚牆為兩廳院原本構造，也是劇場側台常見的紅磚牆面。\r\n劇場人常用的瑞克箱，搖身變成...
# 70   「親子天下Club」成立於2019年7月\r\n是一個共享、共玩、共學的多功能體驗空間\r\...
# 71   一間隱身於中山區巷弄內的「計時制」私設圖書館。我們由衷地希望來到這裡的人們，都能夠閱讀各種形...
# 72   文字圖像，是人們一直以來用來紀錄歷史點滴的媒介；書籍，這些圖文媒介的集結匯流。回想學生時候，...
# 73   公館地區最大二手書店，佔地117坪，藏書破11.6萬本\r\n平均一本書$50\r\n單月有...
# 74   https://www.facebook.com/bookfinder119/?ref=pa...
# 75   https://www.facebook.com/bookfinder119/?ref=pa...
# 76   店主是退化性脊椎損傷患者，曾為找工作所苦，並體認到特殊族群在社會上被接受還有困難，因而成立一...
# 92   從萬大路遷移到目前的東園街，不變的是店內豐富的藏書與五位貓咪店長。除了圖書、CD、DVD銷售...
# 97   可說是公館地區舊書店的異類，店內書籍多為50、60年代的舊書，新書則以店主認定的好書才收購。...
# 100  恬野書是一間以環境土地、身心靈以及社會人文為主題的獨立書店，除了選書、講座相應以上主題之外，...
#
#                       address   longitude   latitude  \
# 5                   重慶南路一段99號  121.507818  25.039382
# 6                    牯嶺街62-2號  121.507818  25.039382
# 7               台北市中正區八德路一段一號  121.559834  25.091075
# 8                      牯嶺街17號  121.507818  25.039382
# 9                   重慶南路一段61號  121.507818  25.039382
# 10                新生南路三段94號1樓  121.542957  25.034544
# 11         台北市大安區溫州街74巷3弄2號1樓  121.542957  25.034544
# 12                      浦城街1號  121.542957  25.034544
# 13          台北市大安區新生南路三段16-1號  121.542957  25.034544
# 14              台北市中正區同安街107號  121.507818  25.039382
# 15    台北市中正區羅斯福路三段244巷10弄2號B1  121.507818  25.039382
# 16               羅斯福路三段301號B1  121.542957  25.034544
# 17                   懷寧街36號8樓  121.507818  25.039382
# 18                     牯嶺街64號  121.507818  25.039382
# 19             八德路一段82巷9弄4號2樓  121.507818  25.039382
# 20                   松江路93巷2號  121.524686  25.072631
# 21          台北市中山區中山北路一段53巷6號  121.524686  25.072631
# 23                  瑞安街224號1樓  121.542957  25.034544
# 24                 復興南路二段173號  121.542957  25.034544
# 25    台北市信義區光復南路133號（松菸文創園區內）  121.544833  25.048305
# 26        復興北路15號14樓之4（1417室）  121.544833  25.048305
# 28            台北市中正區鎮江街 3-1 號  121.507818  25.039382
# 29                   泰順街24號B1  121.542957  25.034544
# 68      10056台北市金山南路一段89巷8號1樓  121.507818  25.039382
# 69   台北市中山南路21-1號 國家戲劇院 愛國東路側  121.507818  25.039382
# 70               建國北路一段126號5樓  121.524686  25.072631
# 71         中山區中山北路一段56巷2之1號2樓  121.524686  25.072631
# 72                光復南路346巷56號  121.542957  25.034544
# 73               羅斯福路三段301號B1  121.542957  25.034544
# 74          羅斯福路三段283巷21弄6號一樓  121.542957  25.034544
# 75               研究院路二段168號1樓  121.592271  25.054501
# 76   106 臺北市臺北市大安區和平東路二段14號B1  121.542957  25.034544
# 92                  東園街66巷59號  121.506498  25.045226
# 97               羅斯福路3段293號B1  121.542957  25.034544
# 100                  信義路二段32號  121.542957  25.034544
#
#                                               openTime  \
# 5                                 一～六｜10:00 - 19:00，日休
# 6                                       一～日11:00-18:00
# 7                                      一-日 10:00-21:00
# 8                                                不定期營業
# 9                                    一～日｜ 9:00 - 22:00
# 10                                         11:00-22:00
# 11                                  週二至週日13:00 - 21:00
# 12                                   一～日｜12:00 - 22:00
# 13                                   週一~週日 14:00-20:00
# 14                週二至四、週日：10:00-18:00。週五、六：10:00-21:00
# 15           週四至週一：14:00-22:00，每週二、三公休（詳細營業時間請依店家公告為主）
# 16                     星期一至六10:30-21:50，星期日13:00-21:00
# 17                                   週二至週日 11:00-20:30
# 18                                   一～日｜10:00 - 20:00
# 19                                            大部分時間不營業
# 20   週一至週六 7:45-21:00 | 週日和國定假日 7:45-18:00 | 每月最後一個...
# 21                          11:00 - 20:00（每月最後一個星期一公休）
# 23                          週二 ~ 日 / 10:30- 18:30 週一公休
# 24                                   一～日｜10:30 - 21:30
# 25                                         09:00-21:00
# 26                 一～五｜09:00 - 19:00，六～日｜14:00 - 19:00
# 28                             週二~週日11:00~18:00 (週一公休)
# 29                                一～日｜16:00 - 22:00，二休
# 68                              周二至周日11:00-20:00(周一店休)
# 69                                         09:00-22:00
# 70                               週二至週六 09:30AM-17:30PM
# 71                      平日:13:00-21:00  六日 14:00-18:00
# 72                          11:00～20:00，週二休息，其他依活動時間而定
# 73                                         12:30-20:00
# 74                                       每日12:30~20:30
# 75                                    週一至週五11:00-19:00
# 76                                   一～日｜12:00 - 22:00
# 92                一～五｜18:00 - 21:00，六｜15:00 - 21:00，日休
# 97                              一～五｜17:00 - 22:00，例假日休
# 100            星期二-星期六，12:00-7:00pm（每月可能稍有不同，以粉絲頁公告為主）
#
#                            phone                     email headCityName  \
# 5                   (02)23110183                       NaN          NaN
# 6                   (02)23214540                       NaN          NaN
# 7                  (02)2341-8865    bleubook2016@gmail.com          NaN
# 8                   (02)23510758                       NaN          NaN
# 9                   (02)23617511                       NaN          NaN
# 10   (02)23620308(聯經#201，上海#202)                       NaN          NaN
# 11                  (02)23622378    nomading2013@gmail.com          NaN
# 12                  (02)23645726                       NaN          NaN
# 13                 (02)2368-8825  livinriverside@gmail.com          NaN
# 14                  (02)23687577    service@kishuan.org.tw          NaN
# 15                 (02)2369 9969  mangasickmanga@gmail.com          NaN
# 16                  (02)23691115                       NaN          NaN
# 17                  (02)23754388                       NaN          NaN
# 18                  (02)23928850                       NaN          NaN
# 19                  (02)23968620                       NaN          NaN
# 20         (02)2509-5085轉753、754     encounter@cwgv.com.tw   遠見‧天下文化事業群
# 21                  (02)25377281        hello@pon-ding.com          NaN
# 23                 (02)2707-7003        act@bufbook.com.tw          NaN
# 24                  (02)27072970                       NaN          NaN
# 25                  (02)27491527  yueyue.service@gmail.com          NaN
# 26                  (02)27773020                       NaN          NaN
# 28                  (02)33221096                       NaN          NaN
# 29                  (02)33652328                       NaN          NaN
# 68                  02-2397-9865     purebookstw@gmail.com          NaN
# 69                   02-23971920        ask@theatercafe.tw          NaN
# 70                   02-25080580          cpclub@cw.com.tw          NaN
# 71                   02-25221795          kulida@gmail.com          NaN
# 72                   02-27769926  orlando@waytoread.com.tw          NaN
# 73                    0223681268       d.liu@lhcmkt.com.tw          NaN
# 74                    0223686808                       NaN          NaN
# 75                    0227830271                       NaN          NaN
# 76                    0233653226                       NaN          NaN
# 92                    0928255107                       NaN          NaN
# 97                    0933122139                       NaN          NaN
# 100                   0958873015     joywildbook@gmail.com          NaN
#
#      cityName groupTypeName  \
# 5    臺北市  中正區          實體書店
# 6    臺北市  中正區          實體書店
# 7         臺北市          實體書店
# 8    臺北市  中正區          實體書店
# 9    臺北市  中正區          實體書店
# 10   臺北市  大安區          實體書店
# 11   臺北市  大安區          實體書店
# 12   臺北市  大安區          實體書店
# 13   臺北市  大安區          實體書店
# 14   臺北市  中正區          實體書店
# 15   臺北市  中正區          實體書店
# 16   臺北市  大安區          實體書店
# 17   臺北市  中正區          實體書店
# 18   臺北市  中正區          實體書店
# 19   臺北市  中正區          實體書店
# 20   臺北市  中山區          實體書店
# 21   臺北市  中山區          實體書店
# 23   臺北市  大安區          實體書店
# 24   臺北市  大安區          實體書店
# 25   臺北市  松山區          實體書店
# 26   臺北市  松山區          實體書店
# 28   臺北市  中正區          實體書店
# 29   臺北市  大安區          實體書店
# 68   臺北市  中正區          實體書店
# 69   臺北市  中正區          實體書店
# 70   臺北市  中山區          實體書店
# 71   臺北市  中山區          實體書店
# 72   臺北市  大安區          實體書店
# 73   臺北市  大安區          實體書店
# 74   臺北市  大安區          實體書店
# 75   臺北市  南港區          實體書店
# 76   臺北市  大安區          實體書店
# 92   臺北市  萬華區          實體書店
# 97   臺北市  大安區          實體書店
# 100  臺北市  大安區          實體書店
#
#                                                    seg city
# 5    [重慶, 販售, 書局, 南路, 創辦, 紅屋, 書街, 風景, 中極具, 過去, 出版品,...  臺北市
# 6    [舊書, 牯嶺, 書舍, 人文, 創始, 隨著國民, 來台, 喜歡, 舊書攤, 開設, 維持...  臺北市
# 7    [獨立, 自由, 建一間屬, 隔絕, 追尋, 這是, 青鳥, 本質, 一種, 論述, 基礎,...  臺北市
# 8    [牯嶺, 當年, 舊書攤, 號的店, 街僅存, 當中, 老字號, 堆疊, 滿屋, 舊書, 風...  臺北市
# 9    [重慶, 南路, 書街, 三民, 超過, 半個, 世紀, 歷史, 可說, 以所謂, 圖書館,...  臺北市
# 10   [聯經, 新生南路, 門市, 不過, 並不, 出版品, 一樓, 聯經書房, 類為, 則是, ...  臺北市
# 11   [旅遊, 流浪ing, 一間, 閱讀, 每個, 國家, 旅行, 分享, 城市, 或是, 藉由...  臺北市
# 12   [店址, 搬遷, 到現, 開業, 超過, 40, 因價格, 輕學子, 光顧, 店內, 種類,...  臺北市
# 13   [工藝, 講座, 文化, 生活, 河邊, 推廣, 台灣, 結合, 藝廊, 經由, 閱讀, 舉...  臺北市
# 14   [文學, 文創, 紀州, 城南, 發展, 協會, 2011, 台灣, 相關, 各式, 涵括,...  臺北市
# 15   [漫畫, Mangasick, 台灣, zine, 展覽, 文化, 2013, 公館, 開業...  臺北市
# 16   [地區, 歷史, 相關, 週邊, 銷售, 產品, 除一樓, 區外, 二樓, 禮品, 則為, ...  臺北市
# 17   [重慶, 南路, 教科, 懷寧, 一帶, 少數, 二手書, 以販售, 大專, 書為, 藝術類...  臺北市
# 18   [牯嶺, 香城, 廈門, 瑩橋, 其後遷, 為書, 可說, 一帶, 規模, 較屬, 現代經營...  臺北市
# 19   [百城, 光華商場, 僅一坪, 空間, 台灣, 商場, 堂成, 留駐, 華商場, 終究, 數...  臺北市
# 20   [空間, 人文, 咖啡, 多姿多采, 九十三, 遠見, 事業, 專屬, 有書, 知識, 進出...  臺北市
# 21   [台灣, 三個, 編輯, 人馬, 出產, 形體, 計畫, 空間, 圖片, 朋丁, pon, ...  臺北市
# 23                        [http, www, buffalo1966, tw]  臺北市
# 24   [泰北, 活動, 1977, 創業, 中國書城, 興趣, 廣泛, 以個, 挑選店, 內藝術,...  臺北市
# 25   [閱樂, 建築, 巨蛋, 展演, 1954, 原為, 場內位, 工業, 時代重, 視員工, ...  臺北市
# 26   [桑格, 頗負, 設計書類, 專賣店, 營業, 30, 店內, 工業, 商業, 設計書, 同...  臺北市
# 28   [沙龍, 左轉, 承繼, 開業, 慕哲, 週週, 辯論, 關注, 議題, 講座, 增設, 期...  臺北市
# 29   [各樣, 活動, 辦理, 音樂, 創作, 認為, 人想, 甚麼, 擁有, 空間, 相當, 店...  臺北市
# 68       [純良, 社是, 社區, 成為, 社區裡, 買書, 找書, 聊書, 據點, 一家, 希望]  臺北市
# 69   [劇場, 紅磚, 隨處, 閱讀, 專業, 分類, 兩廳, 構造, 劇場側, 台常見, 牆面,...  臺北市
# 70   [親子, Club, 體驗, 天下, 2019, 共玩, 共學, 空間, 快樂學習, 展現,...  臺北市
# 71   [一間, 隱身, 巷弄, 計時制, 私設, 圖書館, 人們, 能夠, 閱讀, 各種, 由衷,...  臺北市
# 72   [媒介, 圖像, 人們, 以來, 紀錄, 歷史點, 這些, 圖文, 集結, 匯流, 學生, ...  臺北市
# 73   [公館, 地區, 二手書, 佔地, 117, 藏書破, 11.6, 萬本, 50, 單月, ...  臺北市
# 74   [https, www, facebook, com, bookfinder119, ref...  臺北市
# 75   [https, www, facebook, com, bookfinder119, ref...  臺北市
# 76   [二手書, 損傷, 所苦, 並體, 認到, 社會, 還有, 困難, 一間, 障礙, 就業, ...  臺北市
# 92   [貓咪, 遷移, 東園, 不變, 豐富, 店長, 圖書, CD, DVD, 銷售, 二手書,...  臺北市
# 97   [店主, 位在, 可說, 公館, 地區, 異類, 店內, 多為, 50, 60, 舊書, 新...  臺北市
# 100  [環境, 友善, 再生, 玻璃, 天然, 恬野書, 一間, 身心靈, 社會, 為主題, 獨立...  臺北市

# %%
type(subdata['seg'])
# Out:
# pandas.core.series.Series

# %%
#pandas轉成list
subdata_seg_list = subdata['seg'].tolist()
type(subdata_seg_list)
# Out:
# list

# %%
subdata_seg_list
# Out:
# [['重慶',
#   '販售',
#   '書局',
#   '南路',
#   '創辦',
#   '紅屋',
#   '書街',
#   '風景',
#   '中極具',
#   '過去',
#   '出版品',
#   '現今',
#   '特選',
#   '簡體',
#   '中國',
#   '相當',
#   '一家',
#   '屹立',
#   '喜好',
#   '世界',
#   '古籍',
#   '以其',
#   '自家',
#   '特有',
#   '特色',
#   '人士',
#   '重要'],
#  ['舊書',
#   '牯嶺',
#   '書舍',
#   '人文',
#   '創始',
#   '隨著國民',
#   '來台',
#   '喜歡',
#   '舊書攤',
#   '開設',
#   '維持',
#   '風格',
#   '持續',
#   '證著',
#   '歷史',
#   '退伍',
#   '打理',
#   '老兵',
#   '女婿',
#   '行列',
#   '投入',
#   '依然',
#   '如今',
#   '政府'],
#  ['獨立',
#   '自由',
#   '建一間屬',
#   '隔絕',
#   '追尋',
#   '這是',
#   '青鳥',
#   '本質',
#   '一種',
#   '論述',
#   '基礎',
#   '框限中',
#   '跳躍著',
#   '掙脫',
#   '產生',
#   '連鎖',
#   '風格',
#   '媒體',
#   '未來',
#   '非主流',
#   '二元',
#   '既定',
#   '想像',
#   '不是',
#   '思考',
#   '框架',
#   '主流',
#   '幸福',
#   '像是',
#   '世界'],
#  ['牯嶺',
#   '當年',
#   '舊書攤',
#   '號的店',
#   '街僅存',
#   '當中',
#   '老字號',
#   '堆疊',
#   '滿屋',
#   '舊書',
#   '風景',
#   '蔡家',
#   '兩代',
#   '經營',
#   '充滿',
#   '松林',
#   '父子',
#   '自成',
#   '有名',
#   '一套',
#   '故事',
#   '第一',
#   '一般',
#   '目前'],
#  ['重慶',
#   '南路',
#   '書街',
#   '三民',
#   '超過',
#   '半個',
#   '世紀',
#   '歷史',
#   '可說',
#   '以所謂',
#   '圖書館',
#   '經營',
#   '將各類',
#   '各樣',
#   '圖書',
#   '陳列',
#   '讀者',
#   '選擇',
#   '沒落',
#   '書局',
#   '儼然',
#   '成為',
#   '實體',
#   '指標',
#   '醒目',
#   '架上',
#   '模式',
#   '已有',
#   '自由',
#   '今日',
#   '代表',
#   '之一',
#   '重要'],
#  ['聯經',
#   '新生南路',
#   '門市',
#   '不過',
#   '並不',
#   '出版品',
#   '一樓',
#   '聯經書房',
#   '類為',
#   '則是',
#   '銷售',
#   '簡體',
#   '地亦設',
#   '有門市',
#   '社科',
#   '地下室',
#   '台北',
#   '人文',
#   '中等',
#   '自家',
#   '出版',
#   '上海',
#   '公司'],
#  ['旅遊',
#   '流浪ing',
#   '一間',
#   '閱讀',
#   '每個',
#   '國家',
#   '旅行',
#   '分享',
#   '城市',
#   '或是',
#   '藉由',
#   '為主題',
#   '各樣',
#   '分門',
#   '別類',
#   '書櫃',
#   '適當',
#   '空間裡',
#   '即將',
#   '相關',
#   '規劃',
#   '結束',
#   '回來',
#   '書名',
#   '回憶產',
#   '生共鳴',
#   '無法',
#   '實地',
#   '往國家',
#   '遊歷',
#   '聚會',
#   '週休',
#   '時間',
#   '舉辦',
#   '已經',
#   '當成',
#   '不論',
#   '時間裡',
#   '遊走',
#   '歇遊',
#   '某個',
#   'check',
#   '盡情',
#   '體驗',
#   '當地',
#   '住遊',
#   '還是',
#   '異國',
#   '裡找',
#   '暫時',
#   '瞭解',
#   '居遊',
#   '經驗',
#   '給對',
#   '有興趣',
#   '圖片',
#   '台灣',
#   '推進',
#   '協會',
#   '建構',
#   '行前',
#   '旅人',
#   '文化',
#   '二日',
#   '各式',
#   '地方',
#   '部委',
#   '融入',
#   '放置',
#   '信仰',
#   '日期',
#   '探索',
#   '特定',
#   '以此',
#   '平日',
#   '熟悉',
#   '深入',
#   '一段',
#   '更是',
#   '找到',
#   '精神',
#   '生活',
#   '建立',
#   '只是',
#   '不同',
#   '自己'],
#  ['店址',
#   '搬遷',
#   '到現',
#   '開業',
#   '超過',
#   '40',
#   '因價格',
#   '輕學子',
#   '光顧',
#   '店內',
#   '種類',
#   '豐富',
#   '熱情',
#   '人交談',
#   '講價',
#   '水準',
#   '書局',
#   '浦城',
#   '店主',
#   '便宜',
#   '一大',
#   '特色',
#   '吸引',
#   '早期',
#   '多年',
#   '方式'],
#  ['工藝',
#   '講座',
#   '文化',
#   '生活',
#   '河邊',
#   '推廣',
#   '台灣',
#   '結合',
#   '藝廊',
#   '經由',
#   '閱讀',
#   '舉辦',
#   '展覽',
#   '創造',
#   '社區',
#   '產生',
#   '連結',
#   '互動',
#   '場域',
#   '我們將',
#   '工藝產品',
#   '現代',
#   '消費',
#   '社會',
#   '脈絡',
#   '人們',
#   '體驗',
#   '逐漸',
#   '體察',
#   '經驗並',
#   '內蘊',
#   '感動',
#   '合式',
#   '融入',
#   '都市',
#   '日常生活',
#   '部落',
#   '感受',
#   '深刻',
#   '熟悉',
#   '平台',
#   '生命',
#   '自身',
#   '居民',
#   '方式'],
#  ['文學',
#   '文創',
#   '紀州',
#   '城南',
#   '發展',
#   '協會',
#   '2011',
#   '台灣',
#   '相關',
#   '各式',
#   '涵括',
#   '余光中',
#   '北市',
#   '兼售',
#   '森林',
#   '林海音',
#   '林良',
#   '展演',
#   '鄰近',
#   '廈門',
#   '金門',
#   '牯嶺',
#   '遠至',
#   '師大',
#   '大學區',
#   '戰後',
#   '舉足',
#   '輕重',
#   '場域',
#   '藍星',
#   '詩社',
#   '雜誌',
#   '現代',
#   '媒體',
#   '中國',
#   '文藝',
#   '藝文',
#   '機構',
#   '洪範',
#   '爾雅',
#   '遠流',
#   '王文興',
#   '這一帶',
#   '豐厚',
#   '歷史',
#   '成為',
#   '為主題',
#   '藝文空間',
#   '之新館',
#   '專業',
#   '團隊',
#   '財團',
#   '會經營',
#   '為名',
#   '進行',
#   '推廣',
#   '活動',
#   '12',
#   '24',
#   '開館',
#   '多種',
#   '發生',
#   '這個',
#   '子容納',
#   '創意',
#   '展覽',
#   '以主題',
#   '呈現',
#   '獨立',
#   '各類',
#   '親子',
#   '設計',
#   '圖片',
#   '臉書',
#   '粉絲',
#   '專頁',
#   '閱讀',
#   '推進',
#   '建構',
#   '同安',
#   '合式',
#   '射出去',
#   '文化局',
#   '商品',
#   '副刊',
#   '寄予',
#   '建立',
#   '部委',
#   '出版社',
#   '共享',
#   '刊物',
#   '法人',
#   '新生',
#   '史上',
#   '市政府',
#   '位居',
#   '日期',
#   '彼此',
#   '以此',
#   '作家',
#   '配合',
#   '出版',
#   '可能性',
#   '作品',
#   '正式',
#   '第一',
#   '文化',
#   '包括',
#   '基金'],
#  ['漫畫',
#   'Mangasick',
#   '台灣',
#   'zine',
#   '展覽',
#   '文化',
#   '2013',
#   '公館',
#   '開業',
#   '內閱',
#   '服務',
#   '販售',
#   '精選',
#   '周邊',
#   '代訂',
#   '閱區',
#   '中譯',
#   '藏書以',
#   '為主',
#   '日語',
#   '藏書',
#   '1960',
#   '2010',
#   '各類',
#   '畫冊',
#   '雜誌',
#   '評論',
#   '販售區',
#   '可購',
#   '港四地',
#   '另類',
#   '週邊',
#   '引進',
#   '之餘',
#   '開始將',
#   '引介',
#   '2015',
#   '增設',
#   '空間',
#   '舉辦',
#   '名義',
#   '台日',
#   '兩地',
#   '出版品',
#   '圖片',
#   '閱讀',
#   '推進',
#   '協會',
#   '建構',
#   '作品',
#   '非主流',
#   '日文',
#   '台北市',
#   '不定期',
#   '囊括',
#   '原文',
#   '部委',
#   '刊物',
#   '中文',
#   '每月',
#   '官方',
#   '日期',
#   '部落',
#   '少量',
#   '青年',
#   '作者',
#   '推出',
#   '商品',
#   '及其',
#   '接受',
#   '年代',
#   '日本',
#   '提供',
#   '建立',
#   '包括'],
#  ['地區',
#   '歷史',
#   '相關',
#   '週邊',
#   '銷售',
#   '產品',
#   '除一樓',
#   '區外',
#   '二樓',
#   '禮品',
#   '則為',
#   '地下室',
#   '台大',
#   '文具',
#   '悠久',
#   '基督教',
#   '流行',
#   '及其',
#   '生活',
#   '主要'],
#  ['重慶',
#   '南路',
#   '教科',
#   '懷寧',
#   '一帶',
#   '少數',
#   '二手書',
#   '以販售',
#   '大專',
#   '書為',
#   '藝術類',
#   '個性',
#   '人交談',
#   '少見',
#   '二手',
#   '爽朗',
#   '店主',
#   '人文',
#   '兼有',
#   '景象',
#   '反倒',
#   '街上',
#   '一般',
#   '一些'],
#  ['牯嶺',
#   '香城',
#   '廈門',
#   '瑩橋',
#   '其後遷',
#   '為書',
#   '可說',
#   '一帶',
#   '規模',
#   '較屬',
#   '現代經營',
#   '二手書',
#   '移動式',
#   '書櫃',
#   '明確',
#   '分類',
#   '店內',
#   '空間',
#   '寬敞',
#   '許多',
#   '推拉',
#   '存放',
#   '最具',
#   '更名',
#   '明亮',
#   '原是',
#   '特色',
#   '模式',
#   '位置',
#   '因此',
#   '目前'],
#  ['百城',
#   '光華商場',
#   '僅一坪',
#   '空間',
#   '台灣',
#   '商場',
#   '堂成',
#   '留駐',
#   '華商場',
#   '終究',
#   '數位',
#   '搬遷',
#   '八德',
#   '著其',
#   '擁有',
#   '珍本',
#   '新光',
#   '新天地',
#   '格格不入',
#   '原位',
#   '店面',
#   '重地',
#   '古董',
#   '拆除',
#   '史料',
#   '展示',
#   '唯一',
#   '依然',
#   '如今'],
#  ['空間',
#   '人文',
#   '咖啡',
#   '多姿多采',
#   '九十三',
#   '遠見',
#   '事業',
#   '專屬',
#   '有書',
#   '知識',
#   '進出',
#   '氣息',
#   '進步',
#   '觀念',
#   '激盪',
#   '隱身',
#   '一條',
#   '結合',
#   '誘人',
#   '及點心',
#   '活動',
#   '靜思',
#   '閱讀',
#   '談話',
#   '學習',
#   '場所',
#   '期許',
#   '無形',
#   '人們',
#   '心靈裡',
#   '出現',
#   '份子',
#   '小巷',
#   '提供',
#   '有形',
#   '松江',
#   '台北',
#   '以及',
#   '路上',
#   '天下',
#   '不大',
#   '尤其',
#   '文化',
#   '城市',
#   '可能'],
#  ['台灣',
#   '三個',
#   '編輯',
#   '人馬',
#   '出產',
#   '形體',
#   '計畫',
#   '空間',
#   '圖片',
#   '朋丁',
#   'pon',
#   'ding',
#   '臉書',
#   '粉絲',
#   '專頁',
#   '閱讀',
#   '推進',
#   '協會',
#   '建構',
#   '各式',
#   '部委',
#   '物件',
#   '印尼',
#   '各路',
#   '日期',
#   '朋友',
#   '概念',
#   '共同',
#   '合作',
#   '文化',
#   '日本',
#   '建立'],
#  ['http', 'www', 'buffalo1966', 'tw'],
#  ['泰北',
#   '活動',
#   '1977',
#   '創業',
#   '中國書城',
#   '興趣',
#   '廣泛',
#   '以個',
#   '挑選店',
#   '內藝術',
#   '叢書',
#   '著重',
#   '雜誌',
#   '陳列',
#   '並在',
#   '擔任',
#   '編輯',
#   '並以',
#   '善心人士',
#   '捐贈',
#   '舊書',
#   '偏鄉',
#   '華人學校',
#   '因愛好',
#   '書法',
#   '結合書',
#   '畫家',
#   '促進',
#   '日民間',
#   '地區',
#   '華人',
#   '推廣書法',
#   '兒童',
#   '中華經典',
#   '讀經',
#   '新知',
#   '分送',
#   '致力',
#   '日用品',
#   '品味',
#   '文教',
#   '店主',
#   '南路',
#   '公益',
#   '出版社',
#   '文化交流',
#   '人文',
#   '二十',
#   '夫妻',
#   '年前',
#   '追求',
#   '二人',
#   '教育',
#   '多年',
#   '加上'],
#  ['閱樂',
#   '建築',
#   '巨蛋',
#   '展演',
#   '1954',
#   '原為',
#   '場內位',
#   '工業',
#   '時代重',
#   '視員工',
#   '戰後',
#   '財政廳',
#   '公賣局',
#   '時期',
#   '因營造',
#   '承商',
#   '體系',
#   '傳承',
#   '風格',
#   '2001',
#   '登錄',
#   '歷史',
#   '2004',
#   '興建',
#   '育嬰室',
#   '解體後遷',
#   '生態',
#   '2013',
#   '夢田文創',
#   '戲劇',
#   '巷弄',
#   '裡的',
#   '主場景',
#   '並於拍',
#   '攝後實',
#   '地營運',
#   '2016',
#   '邀請',
#   '人張',
#   '鐵志',
#   '擔任',
#   '總顧問',
#   '開幕',
#   '現在',
#   '藝文',
#   '空間',
#   '創作',
#   '場所',
#   'birthplace',
#   'ideas',
#   '圖片',
#   '臉書',
#   '粉絲',
#   '專頁',
#   '台灣',
#   '閱讀',
#   '推進',
#   '協會',
#   '建構',
#   '池畔',
#   '年成',
#   '奇幻',
#   '文化',
#   '那家',
#   '部委',
#   '松山',
#   '孕育',
#   '福利',
#   '沿用',
#   '咖啡',
#   '省政府',
#   '日期',
#   '配合',
#   '早期',
#   '作品',
#   '材料',
#   '精神',
#   '思想',
#   '重新',
#   '日本',
#   '城市',
#   '代表',
#   '建立',
#   '目前'],
#  ['桑格',
#   '頗負',
#   '設計書類',
#   '專賣店',
#   '營業',
#   '30',
#   '店內',
#   '工業',
#   '商業',
#   '設計書',
#   '同時',
#   '工藝',
#   '攝影',
#   '動畫',
#   '插畫',
#   '建築',
#   '豐富',
#   '類型',
#   '在網',
#   '查詢',
#   '訂購',
#   '迄今已',
#   '各式',
#   '盛名',
#   '亦可',
#   '色彩',
#   '路上'],
#  ['沙龍',
#   '左轉',
#   '承繼',
#   '開業',
#   '慕哲',
#   '週週',
#   '辯論',
#   '關注',
#   '議題',
#   '講座',
#   '增設',
#   '期許',
#   '閱讀',
#   '推動',
#   '成為',
#   '意識',
#   '租借',
#   '凝聚',
#   '咖啡',
#   '公共',
#   '公民',
#   '六年',
#   '平台',
#   '地下',
#   '除了',
#   '文化',
#   '提供'],
#  ['各樣',
#   '活動',
#   '辦理',
#   '音樂',
#   '創作',
#   '認為',
#   '人想',
#   '甚麼',
#   '擁有',
#   '空間',
#   '相當',
#   '店內',
#   '二手書',
#   '社會',
#   '科學為',
#   '販售',
#   '黑膠',
#   '文創',
#   '農產品',
#   '店主人',
#   '唱片',
#   '做些',
#   '偏好',
#   '聚集',
#   '理念',
#   '公共',
#   '交流',
#   '一群',
#   '所在',
#   '投入',
#   '此外',
#   '十分',
#   '重要'],
#  ['純良', '社是', '社區', '成為', '社區裡', '買書', '找書', '聊書', '據點', '一家', '希望'],
#  ['劇場',
#   '紅磚',
#   '隨處',
#   '閱讀',
#   '專業',
#   '分類',
#   '兩廳',
#   '構造',
#   '劇場側',
#   '台常見',
#   '牆面',
#   '搖身',
#   '變成',
#   '展櫃',
#   '可見',
#   '花天',
#   '帕燈',
#   '轉換成',
#   '椅面',
#   '適用',
#   '國家戲',
#   '劇院',
#   '下來',
#   '奧勒岡',
#   '裡面',
#   '培養',
#   '創意',
#   '視野',
#   '傳統',
#   '創新',
#   '展售書',
#   '還有',
#   '各種',
#   '萬用',
#   '瑞克',
#   '象限',
#   '松木',
#   '拆卸',
#   '椅背',
#   '地板',
#   '舞台',
#   '打破',
#   '人生',
#   '原本',
#   '四大',
#   '常用',
#   '坐下',
#   '工具',
#   '模式',
#   '之外',
#   '除了',
#   '很多',
#   '提供',
#   '使用'],
#  ['親子',
#   'Club',
#   '體驗',
#   '天下',
#   '2019',
#   '共玩',
#   '共學',
#   '空間',
#   '快樂學習',
#   '展現',
#   '創意',
#   '實現',
#   '歡迎',
#   '各機構',
#   '團體',
#   '成長',
#   '活動',
#   '發生',
#   'Share',
#   'Enjoy',
#   '多功能',
#   '共享',
#   '大大小小',
#   '一同',
#   '探索',
#   '交流',
#   '期待',
#   '共同',
#   '孩子',
#   '成立',
#   '正在'],
#  ['一間',
#   '隱身',
#   '巷弄',
#   '計時制',
#   '私設',
#   '圖書館',
#   '人們',
#   '能夠',
#   '閱讀',
#   '各種',
#   '由衷',
#   '中山',
#   '希望',
#   '形式'],
#  ['媒介',
#   '圖像',
#   '人們',
#   '以來',
#   '紀錄',
#   '歷史點',
#   '這些',
#   '圖文',
#   '集結',
#   '匯流',
#   '學生',
#   '時候',
#   '手機',
#   '從前',
#   '翻閱',
#   '各樣',
#   '充滿',
#   '語文',
#   '豐富',
#   '多數',
#   '當時',
#   '獨二',
#   '書本',
#   '觸感',
#   '拾起',
#   '平板',
#   '哲理',
#   '回想',
#   '青春',
#   '普及',
#   '智慧',
#   '手上',
#   '文字',
#   '故事',
#   '唯一',
#   '大家',
#   '那些',
#   '一直'],
#  ['公館',
#   '地區',
#   '二手書',
#   '佔地',
#   '117',
#   '藏書破',
#   '11.6',
#   '萬本',
#   '50',
#   '單月',
#   '主題',
#   '書展',
#   '單季',
#   '裝置',
#   '藝術展',
#   '一本',
#   '平均',
#   '最大'],
#  ['https',
#   'www',
#   'facebook',
#   'com',
#   'bookfinder119',
#   'ref',
#   'page',
#   'internal'],
#  ['https',
#   'www',
#   'facebook',
#   'com',
#   'bookfinder119',
#   'ref',
#   'page',
#   'internal'],
#  ['二手書',
#   '損傷',
#   '所苦',
#   '並體',
#   '認到',
#   '社會',
#   '還有',
#   '困難',
#   '一間',
#   '障礙',
#   '就業',
#   '店內',
#   '籍外',
#   '還販售',
#   'CD',
#   '黑膠',
#   '畫作',
#   '族群',
#   '脊椎',
#   '生活用品',
#   '唱片',
#   '各式',
#   '古董',
#   '店主',
#   '身心',
#   '退化',
#   '患者',
#   '特殊',
#   '因而',
#   '接受',
#   '成立',
#   '人士',
#   '支持',
#   '工作'],
#  ['貓咪',
#   '遷移',
#   '東園',
#   '不變',
#   '豐富',
#   '店長',
#   '圖書',
#   'CD',
#   'DVD',
#   '銷售',
#   '二手書',
#   '收購',
#   '店內',
#   '特別售',
#   '相關',
#   '雜貨',
#   '夜間',
#   '週末',
#   '開門',
#   '五位',
#   '店主',
#   '大路',
#   '白天',
#   '另有',
#   '除了',
#   '工作',
#   '因此',
#   '目前'],
#  ['店主',
#   '位在',
#   '可說',
#   '公館',
#   '地區',
#   '異類',
#   '店內',
#   '多為',
#   '50',
#   '60',
#   '舊書',
#   '新書則',
#   '認定',
#   '收購',
#   '舊書經',
#   '營者',
#   '因為',
#   '貨源',
#   '問題',
#   '當年',
#   '開舊',
#   '其實',
#   '相當',
#   '挑戰',
#   '不過',
#   '成為',
#   '尋書',
#   '三峽',
#   '文書苑',
#   '他們',
#   '小高',
#   '半路出家',
#   '分店',
#   '研究者',
#   '年代',
#   '地方',
#   '因此'],
#  ['環境',
#   '友善',
#   '再生',
#   '玻璃',
#   '天然',
#   '恬野書',
#   '一間',
#   '身心靈',
#   '社會',
#   '為主題',
#   '獨立',
#   '選書',
#   '講座',
#   '相應',
#   '主題',
#   '裝潢',
#   '實踐',
#   '隔熱材',
#   '蒐集',
#   '塗料',
#   '舊物',
#   'FSC',
#   '認證',
#   '台灣',
#   '層板',
#   '營運',
#   '目標',
#   '衛生紙',
#   '袋袋',
#   '相傳',
#   '低衝擊',
#   '清潔劑',
#   '供應',
#   '單純',
#   '點心',
#   '飲料',
#   '並販售',
#   '布衛生',
#   '紙筆',
#   '記本',
#   '吸管',
#   '人文',
#   '以及',
#   '雨水',
#   '日常',
#   '成分',
#   '之外',
#   '土地',
#   '除了',
#   '不少',
#   '利用',
#   '以上',
#   '使用',
#   '包括']]

# %%
#for迴圈
flat = [x for sublist in subdata_seg_list for x in sublist]
diction = Counter(flat)
diction.keys()
# Out:
# dict_keys(['重慶', '販售', '書局', '南路', '創辦', '紅屋', '書街', '風景', '中極具', '過去', '出版品', '現今', '特選', '簡體', '中國', '相當', '一家', '屹立', '喜好', '世界', '古籍', '以其', '自家', '特有', '特色', '人士', '重要', '舊書', '牯嶺', '書舍', '人文', '創始', '隨著國民', '來台', '喜歡', '舊書攤', '開設', '維持', '風格', '持續', '證著', '歷史', '退伍', '打理', '老兵', '女婿', '行列', '投入', '依然', '如今', '政府', '獨立', '自由', '建一間屬', '隔絕', '追尋', '這是', '青鳥', '本質', '一種', '論述', '基礎', '框限中', '跳躍著', '掙脫', '產生', '連鎖', '媒體', '未來', '非主流', '二元', '既定', '想像', '不是', '思考', '框架', '主流', '幸福', '像是', '當年', '號的店', '街僅存', '當中', '老字號', '堆疊', '滿屋', '蔡家', '兩代', '經營', '充滿', '松林', '父子', '自成', '有名', '一套', '故事', '第一', '一般', '目前', '三民', '超過', '半個', '世紀', '可說', '以所謂', '圖書館', '將各類', '各樣', '圖書', '陳列', '讀者', '選擇', '沒落', '儼然', '成為', '實體', '指標', '醒目', '架上', '模式', '已有', '今日', '代表', '之一', '聯經', '新生南路', '門市', '不過', '並不', '一樓', '聯經書房', '類為', '則是', '銷售', '地亦設', '有門市', '社科', '地下室', '台北', '中等', '出版', '上海', '公司', '旅遊', '流浪ing', '一間', '閱讀', '每個', '國家', '旅行', '分享', '城市', '或是', '藉由', '為主題', '分門', '別類', '書櫃', '適當', '空間裡', '即將', '相關', '規劃', '結束', '回來', '書名', '回憶產', '生共鳴', '無法', '實地', '往國家', '遊歷', '聚會', '週休', '時間', '舉辦', '已經', '當成', '不論', '時間裡', '遊走', '歇遊', '某個', 'check', '盡情', '體驗', '當地', '住遊', '還是', '異國', '裡找', '暫時', '瞭解', '居遊', '經驗', '給對', '有興趣', '圖片', '台灣', '推進', '協會', '建構', '行前', '旅人', '文化', '二日', '各式', '地方', '部委', '融入', '放置', '信仰', '日期', '探索', '特定', '以此', '平日', '熟悉', '深入', '一段', '更是', '找到', '精神', '生活', '建立', '只是', '不同', '自己', '店址', '搬遷', '到現', '開業', '40', '因價格', '輕學子', '光顧', '店內', '種類', '豐富', '熱情', '人交談', '講價', '水準', '浦城', '店主', '便宜', '一大', '吸引', '早期', '多年', '方式', '工藝', '講座', '河邊', '推廣', '結合', '藝廊', '經由', '展覽', '創造', '社區', '連結', '互動', '場域', '我們將', '工藝產品', '現代', '消費', '社會', '脈絡', '人們', '逐漸', '體察', '經驗並', '內蘊', '感動', '合式', '都市', '日常生活', '部落', '感受', '深刻', '平台', '生命', '自身', '居民', '文學', '文創', '紀州', '城南', '發展', '2011', '涵括', '余光中', '北市', '兼售', '森林', '林海音', '林良', '展演', '鄰近', '廈門', '金門', '遠至', '師大', '大學區', '戰後', '舉足', '輕重', '藍星', '詩社', '雜誌', '文藝', '藝文', '機構', '洪範', '爾雅', '遠流', '王文興', '這一帶', '豐厚', '藝文空間', '之新館', '專業', '團隊', '財團', '會經營', '為名', '進行', '活動', '12', '24', '開館', '多種', '發生', '這個', '子容納', '創意', '以主題', '呈現', '各類', '親子', '設計', '臉書', '粉絲', '專頁', '同安', '射出去', '文化局', '商品', '副刊', '寄予', '出版社', '共享', '刊物', '法人', '新生', '史上', '市政府', '位居', '彼此', '作家', '配合', '可能性', '作品', '正式', '包括', '基金', '漫畫', 'Mangasick', 'zine', '2013', '公館', '內閱', '服務', '精選', '周邊', '代訂', '閱區', '中譯', '藏書以', '為主', '日語', '藏書', '1960', '2010', '畫冊', '評論', '販售區', '可購', '港四地', '另類', '週邊', '引進', '之餘', '開始將', '引介', '2015', '增設', '空間', '名義', '台日', '兩地', '日文', '台北市', '不定期', '囊括', '原文', '中文', '每月', '官方', '少量', '青年', '作者', '推出', '及其', '接受', '年代', '日本', '提供', '地區', '產品', '除一樓', '區外', '二樓', '禮品', '則為', '台大', '文具', '悠久', '基督教', '流行', '主要', '教科', '懷寧', '一帶', '少數', '二手書', '以販售', '大專', '書為', '藝術類', '個性', '少見', '二手', '爽朗', '兼有', '景象', '反倒', '街上', '一些', '香城', '瑩橋', '其後遷', '為書', '規模', '較屬', '現代經營', '移動式', '明確', '分類', '寬敞', '許多', '推拉', '存放', '最具', '更名', '明亮', '原是', '位置', '因此', '百城', '光華商場', '僅一坪', '商場', '堂成', '留駐', '華商場', '終究', '數位', '八德', '著其', '擁有', '珍本', '新光', '新天地', '格格不入', '原位', '店面', '重地', '古董', '拆除', '史料', '展示', '唯一', '咖啡', '多姿多采', '九十三', '遠見', '事業', '專屬', '有書', '知識', '進出', '氣息', '進步', '觀念', '激盪', '隱身', '一條', '誘人', '及點心', '靜思', '談話', '學習', '場所', '期許', '無形', '心靈裡', '出現', '份子', '小巷', '有形', '松江', '以及', '路上', '天下', '不大', '尤其', '可能', '三個', '編輯', '人馬', '出產', '形體', '計畫', '朋丁', 'pon', 'ding', '物件', '印尼', '各路', '朋友', '概念', '共同', '合作', 'http', 'www', 'buffalo1966', 'tw', '泰北', '1977', '創業', '中國書城', '興趣', '廣泛', '以個', '挑選店', '內藝術', '叢書', '著重', '並在', '擔任', '並以', '善心人士', '捐贈', '偏鄉', '華人學校', '因愛好', '書法', '結合書', '畫家', '促進', '日民間', '華人', '推廣書法', '兒童', '中華經典', '讀經', '新知', '分送', '致力', '日用品', '品味', '文教', '公益', '文化交流', '二十', '夫妻', '年前', '追求', '二人', '教育', '加上', '閱樂', '建築', '巨蛋', '1954', '原為', '場內位', '工業', '時代重', '視員工', '財政廳', '公賣局', '時期', '因營造', '承商', '體系', '傳承', '2001', '登錄', '2004', '興建', '育嬰室', '解體後遷', '生態', '夢田文創', '戲劇', '巷弄', '裡的', '主場景', '並於拍', '攝後實', '地營運', '2016', '邀請', '人張', '鐵志', '總顧問', '開幕', '現在', '創作', 'birthplace', 'ideas', '池 ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
mask = np.array(Image.open("1382939234-3435780353.jpg"))#匯入圖片
font = "C:\Windows\Fonts\MSJH.TTC"#字體路徑
#文字雲呈現
wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(diction)
#調整大小
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# -----
# ## 來試試爬蟲抓取Google評論
# * [google map微貳獨冊](https://www.google.com/maps/place/%E5%BE%AE%E8%B2%B3%E7%8D%A8%E5%86%8A/@25.0384613,121.5557041,17z/data=!3m1!5s0x3442abc8991706bb:0x2402cf6df9b024a9!4m7!3m6!1s0x3442abc89903d0e7:0xb2251297f34f74b0!8m2!3d25.0384613!4d121.5557041!9m1!1b1?hl=zh-TW)
# * 利用文字探勘來整理資料
# * 網路爬蟲參考網站：[Python 爬取Google map](https://medium.com/%E8%AA%A4%E9%97%96%E6%95%B8%E6%93%9A%E5%8F%A2%E6%9E%97%E7%9A%84%E5%95%86%E7%AE%A1%E4%BA%BAzino/python-%E7%88%AC%E5%8F%96google-map%E6%9C%80%E6%96%B0%E5%95%86%E5%AE%B6%E8%B3%87%E8%A8%8A%E8%A9%95%E8%AB%96-%E5%AF%A6%E4%BD%9C-%E5%8B%95%E6%85%8B%E7%B6%B2%E9%A0%81-%E7%88%AC%E8%9F%B2-527d66a7e747)

# %%
#引入函式庫
import requests 
import json

# 超連結
url = 'https://www.google.com/maps/preview/review/listentitiesreviews?authuser=0&hl=zh-TW&gl=tw&pb=!1m2!1y3765761116484128999!2y12836686756720899248!2m1!2i10!3e1!4m5!3b1!4b1!5b1!6b1!7b1!5m2!1s0SN1Y8G2H5Om1e8PnO2FyAs!7e81'
# 發送get請求
text = requests.get(url).text
# 取代掉特殊字元，這個字元是為了資訊安全而設定的喔。
pretext = ')]}\''
text = text.replace(pretext,'')
# 把字串讀取成json
soup = json.loads(text)

# 取出包含留言的List 。
conlist = soup[2]

# 逐筆抓出
for i in conlist:
    print("username:"+str(i[0][1]))
    print("time:"+str(i[1]))
    print("comment:"+str(i[3])) #第三項是我們要的評論
# Out:
# username:Emily Lee
# time:1 週前
# comment:非常悠閒的空間，
# 這裡可使用台北通藝文券。
# 裡面很多書都可以看。
#
# 老闆會詳細的介紹茶葉的特色，
# 並且讓客人試問茶葉。
# 茶飲的容器很特別，
# 茶還不錯喝。
# 不收服務費。
#
# 可以使用Line Pay、街口支付、台灣pay等支付方式，
# 發票還可以存手機載具。
# username:Stanley Lin
# time:1 個月前
# comment:一家獨立書店，可以看書配上咖啡，座位不多但非常舒適，喜歡選書店的人請不要錯過！假日的人竟然不多，希望可以一直經營下去，老闆也非常讚會介紹咖啡豆喝起來的感覺與特色，除了選書還有選好茶和好豆子，對了，現煮的鍋煮奶茶也很好喝！
# username:C
# time:10 個月前
# comment:氣氛很好的小書店，茶、咖啡價位較高一些，但用心製作、店內可讀書，喜歡這個空間。
# username:梁子Liangz
# time:1 年前
# comment:很溫暖的獨立書店，還有咖啡茶可以悠閒享用。這裡的書可以翻閱再購買，喜歡閱讀的人一定會喜歡這邊~ (國父紀念館站步行約5分鐘)
# username:Mel
# time:1 年前
# comment:店很棒，氣氛很好👍
# 距離捷運國父紀念館站二號出口步行6-7分鐘
# 距離附近停車場步行3分鐘
# username:Alice CHEN
# time:2 年前
# comment:特色選書，環境沈穩舒適，漫步其中也不怕受打擾。
# 美好的讓人忘了時間，有一種充飽了電可以再重新出發的感覺。
# 喝了一款放鬆茶，真的很香很好喝，從看煮茶的過程、到送上的茶具，都是視覺上的享受。音樂也是，可以說五感被真正的療癒。
# username:Steven Lin
# time:4 年前
# comment:超級棒的獨立書店，店裡也時常舉辦講座或新書發表會之類的，咖啡超棒的，在市區裡有這樣的一個空間真是奢侈的享受！
# username:Cara Huang
# time:3 年前
# comment:店內非常溫馨可愛，也時常與不同作家、藝術家和設計師合作，每次造訪都有小驚喜，手工布丁非常好吃（不過不是每天都有 😂）大推現煮的鍋煮奶茶，濃郁好喝～
# username:peiguei wu
# time:2 年前
# comment:選書有趣，貓咪、女性、哲學、身心靈、旅遊、養生、自然～離信義安和站、國父紀念館站走路19分鐘，地點很不錯👍巷內又安靜，店員十分友善，很推薦的二手書店🌹
# username:Siegfy Chiang
# time:2 週前
# comment:天龍國巷內有這樣的小書店真是不錯，選書品味也很好

# %%
temp = []
# 逐筆抓出
for i in conlist:
    temp.append(i[3])
df = pd.DataFrame(temp)
df.columns = ['comment']
df
# Out:
#                                              comment
# 0  非常悠閒的空間，\n這裡可使用台北通藝文券。\n裡面很多書都可以看。\n\n老闆會詳細的介紹...
# 1  一家獨立書店，可以看書配上咖啡，座位不多但非常舒適，喜歡選書店的人請不要錯過！假日的人竟然不...
# 2            氣氛很好的小書店，茶、咖啡價位較高一些，但用心製作、店內可讀書，喜歡這個空間。
# 3  很溫暖的獨立書店，還有咖啡茶可以悠閒享用。這裡的書可以翻閱再購買，喜歡閱讀的人一定會喜歡這邊...
# 4     店很棒，氣氛很好👍\n距離捷運國父紀念館站二號出口步行6-7分鐘\n距離附近停車場步行3分鐘
# 5  特色選書，環境沈穩舒適，漫步其中也不怕受打擾。\n美好的讓人忘了時間，有一種充飽了電可以再重...
# 6  超級棒的獨立書店，店裡也時常舉辦講座或新書發表會之類的，咖啡超棒的，在市區裡有這樣的一個空間...
# 7  店內非常溫馨可愛，也時常與不同作家、藝術家和設計師合作，每次造訪都有小驚喜，手工布丁非常好吃...
# 8  選書有趣，貓咪、女性、哲學、身心靈、旅遊、養生、自然～離信義安和站、國父紀念館站走路19分鐘...
# 9                           天龍國巷內有這樣的小書店真是不錯，選書品味也很好

# %%
df['yap'] = " "
df.head()
# Out:
#                                                    0 yap
# 0  非常悠閒的空間，\n這裡可使用台北通藝文券。\n裡面很多書都可以看。\n\n老闆會詳細的介紹...
# 1  一家獨立書店，可以看書配上咖啡，座位不多但非常舒適，喜歡選書店的人請不要錯過！假日的人竟然不...
# 2            氣氛很好的小書店，茶、咖啡價位較高一些，但用心製作、店內可讀書，喜歡這個空間。
# 3  很溫暖的獨立書店，還有咖啡茶可以悠閒享用。這裡的書可以翻閱再購買，喜歡閱讀的人一定會喜歡這邊...
# 4     店很棒，氣氛很好👍\n距離捷運國父紀念館站二號出口步行6-7分鐘\n距離附近停車場步行3分鐘

# %%
jieba.load_userdict('./userdict.txt')
jieba.analyse.set_stop_words('stopnew.txt')
index = 0
for documents in df[0]:
    yap_list = jieba.analyse.extract_tags(documents, 150)
    #yap_list = jieba.lcut(documents)
    df['yap'].iloc[index] = yap_list
    index += 1

# %%
df['yap']
# Out:
# 0    [茶葉, 支付, 悠閒, 空間, 台北通藝文券, 裡面, 老闆, 詳細, 介紹, 並且, 試...
# 1    [獨立, 看書, 舒適, 喜歡, 錯過, 經營, 老闆, 感覺, 選書, 還有, 選好, 現...
# 2             [氣氛, 價位, 店內, 讀書, 喜歡, 這個, 空間, 用心, 咖啡, 一些]
# 3    [喜歡, 溫暖, 獨立, 還有, 咖啡茶, 悠閒, 翻閱, 購買, 閱讀, 這邊, 國父紀念...
# 4    [距離, 分鐘, 步行, 氣氛, 捷運, 國父紀念館站, 二號, 停車場, 很棒, 出口, 附近]
# 5    [選書, 環境, 沈穩, 舒適, 打擾, 時間, 一種, 充飽, 了電, 出發, 感覺, 過...
# 6    [超級, 獨立, 店裡, 時常, 舉辦, 講座, 新書, 發表會, 之類, 超棒, 市區裡,...
# 7    [店內, 溫馨, 時常, 藝術家, 設計師, 造訪, 驚喜, 布丁, 不過, 推現, 鍋煮,...
# 8    [選書, 貓咪, 哲學, 身心靈, 旅遊, 養生, 離信義安, 國父紀念館站, 19, 分鐘...
# 9                           [天龍國巷, 這樣, 不錯, 選書, 品味, 真是]
# Name: yap, dtype: object

# %%
yap_list
# Out:
# ['天龍國巷', '這樣', '不錯', '選書', '品味', '真是']

# %%
type(df['yap'])
# Out:
# pandas.core.series.Series

# %%
yap_list = df['yap'].tolist()
type(yap_list)
# Out:
# list

# %%
flat = [x for sublist in yap_list for x in sublist]
diction = Counter(flat)

# %%
diction.keys()
# Out:
# dict_keys(['茶葉', '支付', '悠閒', '空間', '台北通藝文券', '裡面', '老闆', '詳細', '介紹', '並且', '試問', '茶飲', '很特別', '還不錯', '服務費', 'Line', 'Pay', '台灣', 'pay', '發票還', '手機載具', '街口', '使用', '容器', '客人', '特色', '非常', '很多', '方式', '獨立', '看書', '舒適', '喜歡', '錯過', '經營', '感覺', '選書', '還有', '選好', '現煮', '鍋煮', '咖啡豆', '喝起', '好喝', '奶茶', '豆子', '假日', '座位', '咖啡', '不多', '竟然', '一家', '下去', '希望', '除了', '不要', '一直', '氣氛', '價位', '店內', '讀書', '這個', '用心', '一些', '溫暖', '咖啡茶', '翻閱', '購買', '閱讀', '這邊', '國父紀念館站', '分鐘', '享用', '步行', '一定', '距離', '捷運', '二號', '停車場', '很棒', '出口', '附近', '環境', '沈穩', '打擾', '時間', '一種', '充飽', '了電', '出發', '過程', '視覺', '音樂', '的療', '五感', '很香', '煮茶', '漫步', '茶具', '一款', '美好', '不怕', '享受', '真的', '真正', '重新', '其中', '超級', '店裡', '時常', '舉辦', '講座', '新書', '發表會', '之類', '超棒', '市區裡', '這樣', '奢侈', '真是', '溫馨', '藝術家', '設計師', '造訪', '驚喜', '布丁', '不過', '推現', '濃郁', '好吃', '手工', '作家', '每次', '每天', '合作', '不同', '不是', '貓咪', '哲學', '身心靈', '旅遊', '養生', '離信義安', '19', '地點', '不錯', '巷內', '安靜', '店員', '推薦', '二手書', '友善', '有趣', '走路', '女性', '自然', '十分', '天龍國巷', '品味'])

# %%
mask = np.array(Image.open("1382939234-3435780353.jpg"))
font = "C:\Windows\Fonts\MSJH.TTC"
wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(diction)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
