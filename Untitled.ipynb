# %%
d = {
    "年度":"2020","行業別":"工業及服務業","經常性薪資-薪資":"28719"},{"年度":"2020","行業別":"工業","經常性薪資-薪資":"28626"},{"年度":"2020","行業別":"礦業及土石採取業","經常性薪資-薪資":"27851"},{"年度":"2020","行業別":"石油及天然氣礦業","經常性薪資-薪資":"30613"},{"年度":"2020","行業別":"砂、石採取及其他礦業","經常性薪資-薪資":"27228"},{"年度":"2020","行業別":"製造業","經常性薪資-薪資":"28547"},{"年度":"2020","行業別":"食品及飼品製造業","經常性薪資-薪資":"27662"},{"年度":"2020","行業別":"飲料及菸草製造業","經常性薪資-薪資":"30299"},{"年度":"2020","行業別":"紡織業","經常性薪資-薪資":"27614"},{"年度":"2020","行業別":"成衣及服飾品製造業","經常性薪資-薪資":"27849"},{"年度":"2020","行業別":"皮革、毛皮及其製品製造業","經常性薪資-薪資":"27426"},{"年度":"2020","行業別":"木竹製品製造業","經常性薪資-薪資":"27073"},{"年度":"2020","行業別":"紙漿、紙及紙製品製造業","經常性薪資-薪資":"28220"},{"年度":"2020","行業別":"印刷及資料儲存媒體複製業","經常性薪資-薪資":"28138"},{"年度":"2020","行業別":"石油及煤製品製造業","經常性薪資-薪資":"27820"},{"年度":"2020","行業別":"化學原材料、肥料、氮化合物、塑橡膠原料及人造纖維製造業","經常性薪資-薪資":"31377"},{"年度":"2020","行業別":"其他化學製品製造業","經常性薪資-薪資":"29236"},{"年度":"2020","行業別":"藥品及醫用化學製品製造業","經常性薪資-薪資":"29150",},{"年度":"2020","行業別":"橡膠製品製造業","經常性薪資-薪資":"27269"},{"年度":"2020","行業別":"塑膠製品製造業","經常性薪資-薪資":"28162"},{"年度":"2020","行業別":"非金屬礦物製品製造業","經常性薪資-薪資":"29804"},{"年度":"2020","行業別":"基本金屬製造業","經常性薪資-薪資":"28426"},{"年度":"2020","行業別":"金屬製品製造業","經常性薪資-薪資":"27311"},{"年度":"2020","行業別":"電子零組件製造業","經常性薪資-薪資":"29229"},{"年度":"2020","行業別":"電腦、電子產品及光學製品製造業","經常性薪資-薪資":"29786"},{"年度":"2020","行業別":"電力設備及配備製造業","經常性薪資-薪資":"28486"},{"年度":"2020","行業別":"機械設備製造業","經常性薪資-薪資":"28495"},{"年度":"2020","行業別":"汽車及其零件製造業","經常性薪資-薪資":"27892"},{"年度":"2020","行業別":"其他運輸工具及其零件製造業","經常性薪資-薪資":"27976"},{"年度":"2020","行業別":"家具製造業","經常性薪資-薪資":"26506"},{"年度":"2020","行業別":"其他製造業","經常性薪資-薪資":"27367"},{"年度":"2020","行業別":"產業用機械設備維修及安裝業","經常性薪資-薪資":"30090"},{"年度":"2020","行業別":"電力及燃氣
020","行業別":"教育業","經常性薪資-薪資":"27786"},{"年度":"2020","行業別":"學前教育","經常性薪資-薪資":"28302"},{"年度":"2020","行業別":"教育輔助及其他教育業","經常性薪資-薪資":"27176"},{"年度":"2020","行業別":"醫療保健及社會工作服務業","經常性薪資-薪資":"29071"},{"年度":"2020","行業別":"醫療保健業","經常性薪資-薪資":"28980"},{"年度":"2020","行業別":"社會工作服務業","經常性薪資-薪資":"29996"},{"年度":"2020","行業別":"藝術、娛樂及休閒服務業","經常性薪資-薪資":"27076"},{"年度":"2020","行業別":"創作及藝術表演業","經常性薪資-薪資":"29436"},{"年度":"2020","行業別":"運動、娛樂及休閒服務業","經常性薪資-薪資":"26956"},{"年度":"2020","行業別":"其他服務業","經常性薪資-薪資":"25786"},{"年度":"2020","行業別":"個人及家庭用品維修業","經常性薪資-薪資":"26309"},{"年度":"2020","行業別":"美髮及美容美體業","經常性薪資-薪資":"24190"},{"年度":"2020","行業別":"其他個人服務業","經常性薪資-薪資":"26741"}

# %%
d = {

'work1':{
         "行業別":"工業及服務業",
        "wage":"38719"},
'work2':{
         "行業別":"工業",
         "wage":"38626"},
'work3':{
         "行業別":"礦業及土石採取業",
         "wage":"47851"},
'work4':{
         "行業別":"石油及天然氣礦業",
         "wage":"40613"},
'work5':{
         "行業別":"砂、石採取及其他礦業",
         "wage":"57228"}
    }

# %%
type(d)
# Out:
# dict

# %%
d.items()
# Out:
# dict_items([('work1', {'行業別': '工業及服務業', 'wage': '38719'}), ('work2', {'行業別': '工業', 'wage': '38626'}), ('work3', {'行業別': '礦業及土石採取業', 'wage': '47851'}), ('work4', {'行業別': '石油及天然氣礦業', 'wage': '40613'}), ('work5', {'行業別': '砂、石採取及其他礦業', 'wage': '57228'})])

# %%
#定義money()函數，計算總金額和處存罰鍰內容
def money(dict_name): 
    sum = 0
    content = []
    for i in dict_name['wage']: #for key, value in dict_name['罰鍰'].items:
        crime = (i,dict_name['wage'][i]) #crime = (key, value)
        content.append(crime)
        sum += dict_name['wage'][i] #sum += value
    return sum, content

# %%
ranking_m = []
for i in d.items():
    #print(i[1])
    person_money_sum, person_money_content = money(i[1])
    ranking_m.append(person_money_sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 ranking_m = []
#       2 for i in d.items():
#       3     #print(i[1])
# ----> 4     person_money_sum, person_money_content = money(i[1])
#       5     ranking_m.append(person_money_sum)
#
# Input In [25], in money(dict_name)
#       4 content = []
#       5 for i in dict_name['wage']: #for key, value in dict_name['罰鍰'].items:
# ----> 6     crime = (i,dict_name['wage'][i]) #crime = (key, value)
#       7     content.append(crime)
#       8     sum += dict_name['wage'][i] #sum += value
#
# TypeError: string indices must be integers
